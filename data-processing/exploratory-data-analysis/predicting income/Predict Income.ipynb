# %% [markdown]
# This is a practice exercise from the [source](https://www.youtube.com/watch?v=V0u6bxQOUJ8)

# %% [markdown]
# Given attributes about a person, predict whether their income is <=50K or >50K

# %%
import numpy as np
import pandas as pd

df = pd.read_csv('adult.csv', na_values=['#NAME?'])
df.head(5)
# Out:
#     age         workclass    fnlwgt  education  education_num  \
# 0  39.0         State-gov   77516.0  Bachelors           13.0
# 1  50.0  Self-emp-not-inc   83311.0  Bachelors           13.0
# 2  38.0           Private  215646.0    HS-grad            9.0
# 3  53.0           Private  234721.0       11th            7.0
# 4  28.0           Private  338409.0  Bachelors           13.0
#
#        marital_status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black     NaN
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital_gain  capital_loss  hours_per_week native_country income
# 0          2174             0              40  United-States  <=50K
# ...

# %%
# assign outcome as 0 if income <=50K and as 1 if income >50K
df['income'] = [0 if x == "<=50K" else 1 for x in df['income']]

# separate features and outcome into two data frame
# assign X as a DataFrame of features and y as a Series of the outcome variable
X = df.drop('income', 1)
y = df.income

# %%
X.head(5)
# Out:
#     age         workclass    fnlwgt  education  education_num  \
# 0  39.0         State-gov   77516.0  Bachelors           13.0
# 1  50.0  Self-emp-not-inc   83311.0  Bachelors           13.0
# 2  38.0           Private  215646.0    HS-grad            9.0
# 3  53.0           Private  234721.0       11th            7.0
# 4  28.0           Private  338409.0  Bachelors           13.0
#
#        marital_status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black     NaN
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital_gain  capital_loss  hours_per_week native_country
# 0          2174             0              40  United-States
# ...

# %%
y.head(5)
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: income, dtype: int64

# %% [markdown]
# ## Data Cleaning

# %%
# Education is a categorical feature
X['education'].head(5)
# Out:
# 0    Bachelors
# 1    Bachelors
# 2      HS-grad
# 3         11th
# 4    Bachelors
# Name: education, dtype: object

# %%
# Use get_dummies in pandas
pd.get_dummies(X['education'])
